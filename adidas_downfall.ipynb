# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
pd.set_option("display_column.max", None)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-21-92fa691dbf15> in <module>
# ----> 1 pd.set_option("display_column.max", None)
#
# ~/.local/lib/python3.6/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     231
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#     235     @property
#
# ~/.local/lib/python3.6/site-packages/pandas/_config/config.py in _set_option(*args, **kwargs)
#     124
#     125     for k, v in zip(args[::2], args[1::2]):
# --> 126         key = _get_single_key(k, silent)
#     127
#     128         o = _get_registered_option(key)
#
# ~/.local/lib/python3.6/site-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#      89         if not silent:
#      90             _warn_if_deprecated(pat)
# ...

# %%
stock_data = pd.read_csv("/home/user/Desktop/Data_analysis_projects/Shoe_Brands/adidas.csv")

# %%
stock_data["date"] = pd.to_datetime(stock_data["date"])
req_stock_data = stock_data[stock_data["date"].dt.year > 2018]

# %%
req_stock_data
# Out:
#            date  1. open  2. high    3. low  4. close  5. volume
# 3229 2019-01-02   105.42  105.560  104.4500    104.89    32993.0
# 3230 2019-01-03   105.81  105.890  104.5100    104.53    81979.0
# 3231 2019-01-04   107.55  109.190  107.5500    108.78    69738.0
# 3232 2019-01-07   108.61  109.180  108.4200    109.10    82890.0
# 3233 2019-01-08   111.62  111.890  111.0400    111.32    62826.0
# ...         ...      ...      ...       ...       ...        ...
# 4914 2025-09-16   104.59  104.710  103.6600    104.38    45787.0
# 4915 2025-09-17   104.09  106.930  104.0900    105.83    52714.0
# 4916 2025-09-18   106.22  107.130  105.6850    107.00    52845.0
# 4917 2025-09-19   106.53  106.625  105.0000    105.55    45890.0
# 4918 2025-09-22   105.25  106.120  104.7525    105.70    54861.0
#
# [1690 rows x 6 columns]

# %%
overall = pd.read_csv("/home/user/Desktop/Data_analysis_projects/Shoe_Brands/adidas_2019_2024.csv", index_col = 0)

# %%
overall
# Out:
#   Company  Year  Operating_CF  Free_CF  CapEx  Dividends  Share_Repurchases  \
# 0  Adidas  2019          2819     2221    598        664                809
# 1  Adidas  2020          1486     1118    368          0                257
# 2  Adidas  2021          3192     2698    494        585               1000
# 3  Adidas  2022          -479     -983    504        610               2500
# 4  Adidas  2023          2630     2267    363        125                  0
# 5  Adidas  2024          2910     2491    419        125                  0
#
#    Current_Asset  Non_Current_Asset  Total_Assets  ...  \
# 0          10934               9746         20680  ...
# 1          12154               8899         21053  ...
# 2          13944               8193         22137  ...
# 3          11732               8564         20296  ...
# 4           9809               8211         18020  ...
# 5          11904               8751         20655  ...
#
# ...
